# %%
import nltk

# %%
from nltk.chat.util import Chat, reflections

# %%
reflections
# Out:
# {'i am': 'you are',
#  'i was': 'you were',
#  'i': 'you',
#  "i'm": 'you are',
#  "i'd": 'you would',
#  "i've": 'you have',
#  "i'll": 'you will',
#  'my': 'your',
#  'you are': 'I am',
#  'you were': 'I was',
#  "you've": 'I have',
#  "you'll": 'I will',
#  'your': 'my',
#  'yours': 'mine',
#  'you': 'me',
#  'me': 'you'}

# %%
pairs = (
    (r'i like (.*)', 
        (
            'Surely, you can like %1',
            'why, do you like %1?'
        )
    ),
    (r'will you please (.*)', 
        (
            'yeah, sure',
            'no, i can not do this'
        )
    ),
    (r'(.*)python(.*)',
         (
             'python is an interpreted language',
             'python is 4th generation language',
             'python is language of today and tomorrow'             
         )    
    )
)

# %%
cb = Chat(pairs, reflections)

# %%
cb

# %%
cb.converse()
# Out:
# > what is python
# python is language of today and tomorrow
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c456c24e660f> in <module>
# ----> 1 cb.converse()
#
# ~\anaconda3\lib\site-packages\nltk\chat\util.py in converse(self, quit)
#     117             user_input = quit
#     118             try:
# --> 119                 user_input = input(">")
#     120             except EOFError:
#     121                 print(user_input)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
cb.respond('tell me about python')
# Out:
# 'python is an interpreted language'

# %%
qu = 'can python be used for machine learning'

# %%
resp = cb.respond(qu)

# %%
resp
# Out:
# 'python is language of today and tomorrow'

# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\hp\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: comtypes in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3) (1.1.9)
# Requirement already satisfied: pywin32 in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3) (227)
# Requirement already satisfied: pypiwin32 in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3) (223)

# %%
# !pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\hp\anaconda3\lib\site-packages (3.8.1)

# %%
import pyttsx3

# %%
speng = pyttsx3.init()

# %%
speng.setProperty('rate',120)

# %%
speng.say('hello ashutosh')
speng.runAndWait()

# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
import webbrowser as wb

# %%
wb.open_new('https://google.com/search?q=chatbot')
# Out:
# True

# %%
qq = 'i want to purchase mobile'

# %%
qq.split('purchase')[-1].strip()
# Out:
# 'mobile'

# %%
while True:
    with sr.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
        try:
            que = r.recognize_google(audio)
            if que == 'exit':
                break            
            print('you said:',que)
            resp = cb.respond(que)
            if resp:
                print('Bot:',resp)
                speng.say(resp)
                speng.runAndWait()
            else:
                if 'search' in que:
                    if 'chatbot' in que:
                        wb.open_new('https://google.com/search?q=chatbot')
                    elif 'games' in que:
                        wb.open_new('https://google.com/search?q=games')
                elif 'purchase' in que:
                    query = que.split('purchase')[-1].strip()
                    wb.open_new('https://flipkart.com/search?q={}'.format(query))            
            print('-'*20)
        except Exception as e:
            print('error')
            print(e)
# Out:
# you said: I want to purchase iPhone I want to purchase mobile
# --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-0eb9efe59722> in <module>
#       2     with sr.Microphone() as source:
#       3         r.adjust_for_ambient_noise(source)
# ----> 4         audio = r.listen(source)
#       5         try:
#       6             que = r.recognize_google(audio)
#
# ~\anaconda3\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# ~\anaconda3\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# ~\anaconda3\lib\site-packages\pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\hp\anaconda3\lib\site-packages (0.3.8)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from pytesseract) (8.2.0)

# %%
path = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
 import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = path

# %%
img = Image.open('img for ocr.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=390x210 at 0x214543A14F0>

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# "hey hello Ashutosh\nHow Are you\n\nit's working fine\n\x0c"

# %%
print(text)
# Out:
# hey hello Ashutosh
# How Are you
#
# it's working fine

# %%
img2 = Image.open('Captured.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1014x431 at 0x2144C8AFFD0>

# %%
text2 = pytesseract.image_to_string(img2)
print(text2)
# Out:
# APPLE iPhone 12 (White, 128 GB)
# 6,486 Ratings & 525 Reviews
#
# 128 GB ROM
#
# 15.49 cm (6.1 inch) Super Retina XDR Display
#
# 12MP + 12MP | 12MP Front Camera
#
# A14 Bionic Chip with Next Generation Neural Engine Processor
# Ceramic Shield
#
# IP68 Water Resistance
#
# All Screen OLED Display
#
# Add to Compare Brand Warranty for 1 Year

# %%
Image.open('R.jfif')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700 at 0x2145443EE50>

# %%
text3 = pytesseract.image_to_string(Image.open('R.jfif'))
print(text3)
# Out:
# Today is a new day,
# So renew your mind this morning.
# Be positive and start fresh.
# Good Morning
# Have a great day ahead.
