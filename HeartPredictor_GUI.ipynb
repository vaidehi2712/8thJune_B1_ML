# %%
import pandas as pd 
import numpy as np 
import tkinter as tk 
import warnings 
warnings.filterwarnings('ignore')
import sklearn as skl

# %%
m =pd.read_pickle(r'Heart.pkl')

app = tk.Tk()
app.geometry('450x500')
app.title('Heart Attack Preionctople(2)

canvas = tk.Canvas(app,width=450,height=500)
canvas.pack(fill='both',expnd=True)
#canvas.creat,0,image=bg,anchor='nw')
canvas.create_text(220,10,text='Heart Attack Prediction')

def Predict():
    age = eval(Entry_Age.get())
    sex = eval(Entry_Sex.get())
    trestbp = eval(Entry_Trestbp.get())
    chols = eval(Entry_chols.get())
    fbs = eval(Entry_Fbs.get())
    rest = eval(Entry_Rest.get())
    thalachs = eval(Entry_Thalachs.get())
    exangs = eval(Entry_Exangs.get())
    oldpeaks = eval(Entry_OldPeak.get())
    slops = eval(Entry_Slopes.get())
    cas = eval(Entry_Ca.get())
    cp1 = eval(Entry_Cp1.get())
    cp2 = eval(Entry_Cp2.get())
    cp3 = eval(Entry_Cp3.get())
    cp4 = eval(Entry_Cp4.get())
    thal0 = cp1 = eval(Entry_Thal0.get())
    thal1 = cp1 = eval(Entry_Thal1.get())
    thal2 = cp1 = eval(Entry_Thal2.get())
    thal3 = cp1 = eval(Entry_Thal3.get())
    inp = pd.DataFrame({'Age':[age],'Sex':[sex],'TrestBP':[trestbp],'Chol':[chols],'FBS':[fbs],'RestECG':[rest],'Thalach':[thalachs],'Exang':[exangs],'OldPeak':[oldpeaks],'Slope':[slops],'Ca':[cas],'CP1':[cp1],'CP2':[cp2],'CP3':[cp3],'CP4':[cp4],'Thal0':[thal0],'Thal1':[thal1],'Thal2':[thal2],'Thal3':[thal3]})
    result.set(round(m.predict(inp)[0],2))

#for the input---->
Age=canvas.create_text(100,60,anchor='nw',text='Enter Your Age')
Sex=canvas.create_text(100,80,anchor='nw',text='Enter Your Sex')
Trestbp=canvas.create_text(100,100,anchor='nw',text='Enter Your TrestBP')
Chols=canvas.create_text(100,120,anchor='nw',text='Enter Your Chol Level')
Fbs=canvas.create_text(100,140,anchor='nw',text='Enter Fbs')
Rest=canvas.create_text(100,160,anchor='nw',text='Enter Your RestECG')
Thalachs=canvas.create_text(100,180,anchor='nw',text='Enter Thalachs')
Exangs=canvas.create_text(100,200,anchor='nw',text='Enter The Exang')
OldPeak=canvas.create_text(100,220,anchor='nw',text='Enter Your OldPeak')
Slopes=canvas.create_text(100,240,anchor='nw',text='Enter Slope')
Cas=canvas.create_text(100,260,anchor='nw',text='Enter the Ca Level')
Cp1=canvas.create_text(100,280,anchor='nw',text='Enter Cp1')
Cp2=canvas.create_text(100,300,anchor='nw',text='Enter Cp2')
Cp3=canvas.create_text(100,320,anchor='nw',text='Enter Cp3')
Cp4=canvas.create_text(100,340,anchor='nw',text='Enter Cp4')
Thal0=canvas.create_text(100,360,anchor='nw',text='Enter Thal0')
Thal1=canvas.create_text(100,380,anchor='nw',text='Enter Thal1')
Thal2=canvas.create_text(100,400,anchor='nw',text='Enter Thal2')
Thal3=canvas.create_text(100,420,anchor='nw',text='Enter Thal3')


#widgets---->
Entry_Age=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Age).place(x=260,y=60,height=20)

Entry_Sex=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Sex).place(x=260,y=80,height=20)

Entry_Trestbp=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Trestbp).place(x=260,y=100,height=20)

Entry_chols=tk.Variable(app)
tk.Entry(app,textvariable=Entry_chols).place(x=260,y=120,height=20)

Entry_Fbs=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Fbs).place(x=260,y=140,height=20)

Entry_Rest=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Rest).place(x=260,y=160,height=20)

Entry_Thalachs=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Thalachs).place(x=260,y=180,height=20)

Entry_Exangs=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Exangs).place(x=260,y=200,height=20)

Entry_OldPeak=tk.Variable(app)
tk.Entry(app,textvariable=Entry_OldPeak).place(x=260,y=220,height=20)

Entry_Slopes=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Slopes).place(x=260,y=240,height=20)

Entry_Ca=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Ca).place(x=260,y=260,height=20)

Entry_Cp1=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Cp1).place(x=260,y=280,height=20)

Entry_Cp2=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Cp2).place(x=260,y=300,height=20)

Entry_Cp3=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Cp3).place(x=260,y=320,height=20)

Entry_Cp4=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Cp4).place(x=260,y=340,height=20)

Entry_Thal0=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Thal0).place(x=260,y=360,height=20)

Entry_Thal1=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Thal1).place(x=260,y=380,height=20)

Entry_Thal2=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Thal2).place(x=260,y=400,height=20)

Entry_Thal3=tk.Variable(app)
tk.Entry(app,textvariable=Entry_Thal3).place(x=260,y=420,height=20)


#for Prediction---->
tk.Button(app,text='Predict Health',command=Predict,bg='light blue').place(x=260,y=445,height=20)

predicted_output=tk.Variable(app)
predicted_output.set('Your Health')
tk.Label(app,textvariable=predicted_output).place(x=100,y=470)

result=tk.Variable(app)
result.set('')
tk.Entry(app,textvariable=result).place(x=260,y=470,height=20)

app.mainloop()
# Out:
#   File "<ipython-input-6-28987bc99110>", line 5
#     app.title('Heart Attack Preionctople(2)
#                                            ^
# SyntaxError: EOL while scanning string literal
